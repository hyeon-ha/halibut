# %%
import pandas as pd

hong_sung = pd.read_csv("uit_feeding_hy_624_홍성금평.csv")

hong_sung_file  = pd.DataFrame(hong_sung)
print(hong_sung_file)
print(type(hong_sung.columns))
print(hong_sung.shape)
# Out:
#          input_dt donsa_cd group_id  eq_id feed_plan_cd  ilcha feed_plan_nm  \
# 0      2018-06-20        B        a      1           B2      6           2산
# 1      2018-06-20        B        a      2           B2      4           2산
# 2      2018-06-20        B        a      6           B2      6           2산
# 3      2018-06-20        B        a      7           B3      6          3산+
# 4      2018-06-20        B        a      8           B3      6          3산+
# ...           ...      ...      ...    ...          ...    ...          ...
# 15247  2022-06-15        B        a     16           B4      7       지혜팜김태규
# 15248  2022-06-15        B        a     17           B4     12       지혜팜김태규
# 15249  2022-06-15        B        a     18           B4     12       지혜팜김태규
# 15250  2022-06-15        B        a     25           B4     30       지혜팜김태규
# 15251  2022-06-15        B        a     35           B4     30       지혜팜김태규
#
# ...

# %%
import pandas as pd

pigplan_624 = pd.read_csv('/mnt/d/project/comars/pigplan_624.csv')

print(pigplan_624)
pigplan_624  = pd.DataFrame(pigplan_624)
# Out:
#       FARM_NO  Unnamed: 1 FARM_PIG_NO  Unnamed: 3  BUNMAN_SANCHA  Unnamed: 5  \
# 0         624         NaN       36-86         NaN              2         NaN
# 1         624         NaN       36-86         NaN              3         NaN
# 2         624         NaN       36-86         NaN              4         NaN
# 3         624         NaN       36-86         NaN              5         NaN
# 4         624         NaN       36-86         NaN              6         NaN
# ...       ...         ...         ...         ...            ...         ...
# 2459      624         NaN     041-025         NaN              1         NaN
# 2460      624         NaN     041-031         NaN              1         NaN
# 2461      624         NaN     034-087         NaN              1         NaN
# 2462      624         NaN     035-006         NaN              1         NaN
# 2463      624         NaN     036-020         NaN              1         NaN
#
# ...

# %%
pigplan_624_proprecessing = pigplan_624.iloc[ :, list(range(0,21,2))]

# %%
pigplan_624_proprecessing
# Out:
#       FARM_NO FARM_PIG_NO  BUNMAN_SANCHA  GYOBAE_DT  BUNMAN_DT  CHONGSAN  \
# 0         624       36-86              2   20100521   20100913        13
# 1         624       36-86              3   20101009   20110202        18
# 2         624       36-86              4   20110309   20110703        13
# 3         624       36-86              5   20110801   20111125        13
# 4         624       36-86              6   20111227   20120421        17
# ...       ...         ...            ...        ...        ...       ...
# 2459      624     041-025              1   20220119   20220514        11
# 2460      624     041-031              1   20211228   20220418        10
# 2461      624     034-087              1   20211203   20220328        12
# 2462      624     035-006              1   20211218   20220412        10
# 2463      624     036-020              1   20211225   20220421        17
#
#       SILSAN  EUDUSU  EUKG  CHOGYOBAE  JAE
# 0         13      11   0.0        NaN  NaN
# ...
